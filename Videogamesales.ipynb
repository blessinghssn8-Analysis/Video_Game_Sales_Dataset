# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
videogamesale=pd.read_csv('/content/drive/MyDrive/Classroom/Data Science Google Meet: https:  meet.google.com fto-vikn-wne/Data structure/video Game sales/Video Game Sales Data.csv')

# %%
videogamesale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
videogamesale.shape
# Out:
# (16598, 11)

# %%
videogamesale.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
videogamesale['Year'].fillna(0000, inplace =True)
# Out:
# <ipython-input-82-451827d56f78>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   videogamesale['Year'].fillna(0000, inplace =True)

# %%
videogamesale['Publisher'].fillna('Missing', inplace =True)

# %%
videogamesale.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
videogamesale.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
videogamesale.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
videogamesale.iloc[0:20]
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
videogamesale.iloc[19:40]
# Out:
#     Rank                                          Name Platform    Year  \
# 19    20  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
# 20    21                 Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 21    22                              Super Mario Land       GB  1989.0
# 22    23                           Super Mario Bros. 3      NES  1988.0
# 23    24                            Grand Theft Auto V     X360  2013.0
# 24    25                   Grand Theft Auto: Vice City      PS2  2002.0
# 25    26                 Pokemon Ruby/Pokemon Sapphire      GBA  2002.0
# 26    27                   Pokemon Black/Pokemon White       DS  2010.0
# 27    28   Brain Age 2: More Training in Minutes a Day       DS  2005.0
# 28    29                        Gran Turismo 3: A-Spec      PS2  2001.0
# 29    30                Call of Duty: Modern Warfare 3     X360  2011.0
# 30    31       Pokémon Yellow: Special Pikachu Edition       GB  1998.0
# ...

# %%
# Top 10 best-selling games globally
top10_global_sales = videogamesale[['Name', 'Platform', 'Genre', 'Publisher', 'Global_Sales']].sort_values(by='Global_Sales', ascending=False).head(10)
top10_global_sales
# Out:
#                         Name Platform         Genre Publisher  Global_Sales
# 0                 Wii Sports      Wii        Sports  Nintendo         82.74
# 1          Super Mario Bros.      NES      Platform  Nintendo         40.24
# 2             Mario Kart Wii      Wii        Racing  Nintendo         35.82
# 3          Wii Sports Resort      Wii        Sports  Nintendo         33.00
# 4   Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo         31.37
# 5                     Tetris       GB        Puzzle  Nintendo         30.26
# 6      New Super Mario Bros.       DS      Platform  Nintendo         30.01
# 7                   Wii Play      Wii          Misc  Nintendo         29.02
# 8  New Super Mario Bros. Wii      Wii      Platform  Nintendo         28.62
# 9                  Duck Hunt      NES       Shooter  Nintendo         28.31

# %%
top10_other_sales = videogamesale[['Name', 'Platform', 'Genre', 'Publisher', 'Other_Sales']].sort_values(by='Other_Sales', ascending=False).head(10)
top10_other_sales
# Out:
#                               Name Platform       Genre  \
# 17   Grand Theft Auto: San Andreas      PS2      Action
# 0                       Wii Sports      Wii      Sports
# 47                  Gran Turismo 4      PS2      Racing
# 16              Grand Theft Auto V      PS3      Action
# 2                   Mario Kart Wii      Wii      Racing
# 3                Wii Sports Resort      Wii      Sports
# 348      Pro Evolution Soccer 2008      PS2      Sports
# 6            New Super Mario Bros.       DS    Platform
# 7                         Wii Play      Wii        Misc
# 10                      Nintendogs       DS  Simulation
#
#                         Publisher  Other_Sales
# 17           Take-Two Interactive        10.57
# 0                        Nintendo         8.46
# 47    Sony Computer Entertainment         7.53
# 16           Take-Two Interactive         4.14
# 2                        Nintendo         3.31
# 3                        Nintendo         2.96
# ...

# %%
top10_JP_sales = videogamesale[['Name', 'Platform', 'Genre', 'Publisher', 'JP_Sales']].sort_values(by='JP_Sales', ascending=False).head(10)
top10_JP_sales
# Out:
#                                             Name Platform         Genre  \
# 4                       Pokemon Red/Pokemon Blue       GB  Role-Playing
# 12                   Pokemon Gold/Pokemon Silver       GB  Role-Playing
# 1                              Super Mario Bros.      NES      Platform
# 6                          New Super Mario Bros.       DS      Platform
# 20                 Pokemon Diamond/Pokemon Pearl       DS  Role-Playing
# 26                   Pokemon Black/Pokemon White       DS  Role-Playing
# 25                 Pokemon Ruby/Pokemon Sapphire      GBA  Role-Playing
# 41                   Animal Crossing: Wild World       DS    Simulation
# 27   Brain Age 2: More Training in Minutes a Day       DS        Puzzle
# 214                     Monster Hunter Freedom 3      PSP  Role-Playing
#
#     Publisher  JP_Sales
# 4    Nintendo     10.22
# 12   Nintendo      7.20
# 1    Nintendo      6.81
# 6    Nintendo      6.50
# 20   Nintendo      6.04
# ...

# %%
top10_EU_sales = videogamesale[['Name', 'Platform', 'Genre', 'Publisher', 'EU_Sales']].sort_values(by='EU_Sales', ascending=False).head(10)
top10_EU_sales
# Out:
#                                             Name Platform         Genre  \
# 0                                     Wii Sports      Wii        Sports
# 2                                 Mario Kart Wii      Wii        Racing
# 3                              Wii Sports Resort      Wii        Sports
# 10                                    Nintendogs       DS    Simulation
# 16                            Grand Theft Auto V      PS3        Action
# 19  Brain Age: Train Your Brain in Minutes a Day       DS          Misc
# 6                          New Super Mario Bros.       DS      Platform
# 7                                       Wii Play      Wii          Misc
# 4                       Pokemon Red/Pokemon Blue       GB  Role-Playing
# 14                                  Wii Fit Plus      Wii        Sports
#
#                Publisher  EU_Sales
# 0               Nintendo     29.02
# 2               Nintendo     12.88
# 3               Nintendo     11.01
# ...

# %%
top10_NA_sales = videogamesale[['Name', 'Platform', 'Genre', 'Publisher', 'NA_Sales']].sort_values(by='NA_Sales', ascending=False).head(10)
top10_NA_sales
# Out:
#                          Name Platform     Genre               Publisher  \
# 0                  Wii Sports      Wii    Sports                Nintendo
# 1           Super Mario Bros.      NES  Platform                Nintendo
# 9                   Duck Hunt      NES   Shooter                Nintendo
# 5                      Tetris       GB    Puzzle                Nintendo
# 2              Mario Kart Wii      Wii    Racing                Nintendo
# 3           Wii Sports Resort      Wii    Sports                Nintendo
# 15         Kinect Adventures!     X360      Misc  Microsoft Game Studios
# 8   New Super Mario Bros. Wii      Wii  Platform                Nintendo
# 7                    Wii Play      Wii      Misc                Nintendo
# 18          Super Mario World     SNES  Platform                Nintendo
#
#     NA_Sales
# 0      41.49
# 1      29.08
# 9      26.93
# 5      23.20
# 2      15.85
# 3      15.75
# 15     14.97
# 8      14.59
# 7      14.03
# 18     12.78

# %%
top10_JPother_sales = videogamesale[['Name', 'Platform', 'Genre', 'Publisher', "JP_Sales", 'Other_Sales']].sort_values(by=["JP_Sales",'Other_Sales'], ascending=False).head(10)
top10_JPother_sales
# Out:
#                                             Name Platform         Genre  \
# 4                       Pokemon Red/Pokemon Blue       GB  Role-Playing
# 12                   Pokemon Gold/Pokemon Silver       GB  Role-Playing
# 1                              Super Mario Bros.      NES      Platform
# 6                          New Super Mario Bros.       DS      Platform
# 20                 Pokemon Diamond/Pokemon Pearl       DS  Role-Playing
# 26                   Pokemon Black/Pokemon White       DS  Role-Playing
# 25                 Pokemon Ruby/Pokemon Sapphire      GBA  Role-Playing
# 41                   Animal Crossing: Wild World       DS    Simulation
# 27   Brain Age 2: More Training in Minutes a Day       DS        Puzzle
# 214                     Monster Hunter Freedom 3      PSP  Role-Playing
#
#     Publisher  JP_Sales  Other_Sales
# 4    Nintendo     10.22         1.00
# 12   Nintendo      7.20         0.71
# 1    Nintendo      6.81         0.77
# ...

# %%
# Regional sales comparison for the top 10 best-selling games
topRegionalsales = videogamesale[['Name', 'NA_Sales', ]].sort_values(by='NA_Sales', ascending=False).head(10)
topRegionalsales
# Out:
#                          Name  NA_Sales
# 0                  Wii Sports     41.49
# 1           Super Mario Bros.     29.08
# 9                   Duck Hunt     26.93
# 5                      Tetris     23.20
# 2              Mario Kart Wii     15.85
# 3           Wii Sports Resort     15.75
# 15         Kinect Adventures!     14.97
# 8   New Super Mario Bros. Wii     14.59
# 7                    Wii Play     14.03
# 18          Super Mario World     12.78

# %%
videogamesale.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   1973.647307      0.264667      0.146652      0.077782
# std     4791.853933    254.346809      0.816683      0.505351      0.309291
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
gamesale = videogamesale

# %%
gamesale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
gamesale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
publisher_counts = gamesale['Publisher'].value_counts()

# %%
publisher_counts
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Glams                              1
# Locus                              1
# Warp                               1
# Elite                              1
# UIG Entertainment                  1
# Name: count, Length: 579, dtype: int64

# %%
top_5publishers = publisher_counts.head(5)

# %%
top_5publishers
# Out:
# Publisher
# Electronic Arts                 1354
# Activision                       977
# Namco Bandai Games               939
# Ubisoft                          925
# Konami Digital Entertainment     834
# Name: count, dtype: int64

# %%
# total_sales_per_genre = gamesale.groupby('Name').sum('NA_Sales')
total_sales_per_genre = gamesale.groupby('Name')['NA_Sales'].sum()

# %%
total_sales_per_genre.sort_values(ascending=False)
# Out:
# Name
# Wii Sports                                         41.49
# Super Mario Bros.                                  32.48
# Duck Hunt                                          26.93
# Tetris                                             26.17
# Grand Theft Auto V                                 23.46
#                                                    ...
# Pop Cutie! Street Fashion Simulation (JP sales)     0.00
# Pony Friends                                        0.00
# Policenauts                                         0.00
# Dragon Force                                        0.00
# ¡Shin Chan Flipa en colores!                        0.00
# Name: NA_Sales, Length: 11493, dtype: float64

# %%
wii_games = gamesale[gamesale['Platform'] == 'Wii']

# %%
Mario_games = gamesale[gamesale['Name']== 'Mario']

# %%
Mario_games
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
wii_games
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# ...      ...                                                ...      ...
# 16517  16520                       Teenage Mutant Ninja Turtles      Wii
# 16552  16555           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16581  16584                                          Fit & Fun      Wii
#
#          Year     Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
Sales_by_Year = gamesale.groupby('Year')['Global_Sales'].sum()

# %%
gamesale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
Sales_by_Year.sort_values(ascending=False)
# Out:
# Year
# 2008.0    693.96
# 2009.0    670.20
# 2007.0    619.68
# 2010.0    615.16
# 2006.0    527.55
# 2011.0    517.93
# 2005.0    461.76
# 2004.0    422.79
# 2002.0    402.12
# 2013.0    370.78
# 2012.0    368.80
# 2003.0    363.22
# 2014.0    339.23
# 2001.0    334.79
# 2015.0    265.93
# 1998.0    259.34
# 1999.0    253.10
# 1997.0    209.69
# 2000.0    203.24
# 1996.0    200.01
# 1995.0     89.18
# 1994.0     79.43
# 1992.0     76.16
# 1989.0     73.45
# 2016.0     71.61
# 1985.0     53.94
# 1984.0     50.36
# 1990.0     49.39
# 1988.0     47.22
# 1993.0     45.98
# 1986.0     37.07
# 1981.0     35.77
# 1991.0     32.49
# 1982.0     28.86
# 1987.0     21.74
# 1983.0     16.79
# 1980.0     11.38
# 2020.0      0.29
# 2017.0      0.05
# Name: Global_Sales, dtype: float64

# %%
 sales_by_genre = gamesale.groupby('Genre')[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()

# %%
top_genre_na = sales_by_genre['NA_Sales'].idxmax()
top_genre_eu = sales_by_genre['EU_Sales'].idxmax()
top_genre_jp = sales_by_genre['JP_Sales'].idxmax()
top_genre_other = sales_by_genre['Other_Sales'].idxmax()

# %%
top_genre_na
# Out:
# 'Action'

# %%
gamesale.to_csv('/content/drive/MyDrive/Classroom/Data Science Google Meet: https:  meet.google.com fto-vikn-wne/Data structure/video Game sales/output.csv')
